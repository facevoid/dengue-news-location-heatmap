# %%
import json
import pandas as pd
from plot_utils import plot_date_vs_news_count_on_dengue, plot_bar_chart

# %% [markdown]
# # Date wise news for the year 2018

# %%
with open('data_for_plot/date_wise_news_sorted_2018.json') as fp:
    date_wise_news = json.load(fp)
    plot_date_vs_news_count_on_dengue(date_wise_news)

# %% [markdown]
# # Date wise news for the year 2019

# %%
with open('data_for_plot/date_wise_news_sorted_2019.json') as fp:
    date_wise_news = json.load(fp)
    plot_date_vs_news_count_on_dengue(date_wise_news)

# %% [markdown]
# # District names appeared at the news on Dengue

# %%
df = pd.read_csv('data_for_heatmap/district_wise_dengue_news_count.csv')
X = list(df['location_name_english'])
y = list(df['count'])
plot_bar_chart(X,y, xlabel = 'District Names', ylabel= 'News Count')

# %% [markdown]
# # Thana names of Dhaka city appeared at the news on Dengue

# %%
df = pd.read_csv('data_for_heatmap/thana_wise_dengue_news.csv')
X = list(df['location_name_english'])
y = list(df['count'])
plot_bar_chart(X,y, xlabel = 'Thana names of Dhaka', ylabel= 'News Count')

# %% [markdown]
# # DNCC location names appeared at the news on Dengue

# %%
df = pd.read_csv('data_for_heatmap/dncc_dengue_news_count_location_wise_v2.csv')
X = list(df['location_name_english'])
y = list(df['count'])
plot_bar_chart(X, y, xlabel = 'location name dncc', ylabel = 'appearence in dengue news')

# %% [markdown]
# # DSCC location names appeared at the news on Dengue

# %%
df = pd.read_csv('data_for_heatmap/dscc_dengue_news_count_location_wise_v2.csv')
X = list(df['location_name_english'])
y = list(df['count'])
plot_bar_chart(X, y, xlabel = 'location name dscc', ylabel = 'appearence in dengue news')
