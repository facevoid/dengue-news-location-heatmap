# %%
import json
import pandas as pd
from plot_utils import plot_date_vs_news_count_on_dengue, plot_bar_chart

# %%
with open('plot_data/date_wise_news_sorted_2018.json') as fp:
    date_wise_news = json.load(fp)
    plot_date_vs_news_count_on_dengue(date_wise_news)

# %%
with open('plot_data/date_wise_news_sorted_2019.json') as fp:
    date_wise_news = json.load(fp)
    plot_date_vs_news_count_on_dengue(date_wise_news)

# %%
df = pd.read_csv('data_for_heatmap/district_wise_dengue_news_count.csv')
X = list(df['location_name_english'])
y = list(df['count'])
plot_bar_chart(X,y, xlabel = 'District Names', ylabel= 'News Count')

# %%
df = pd.read_csv('data_for_heatmap/thana_wise_dengue_news.csv')
X = list(df['location_name_english'])
y = list(df['count'])
plot_bar_chart(X,y, xlabel = 'Thana names of Dhaka', ylabel= 'News Count')
